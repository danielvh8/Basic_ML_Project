# %%
import numpy as np
import tensorflow as tf
import sklearn
import pandas as pd

import matplotlib.pyplot as plt
import math
import seaborn as sns
import sklearn
import itertools
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
import numpy as np, pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_validate

# %%
trainData = pd.read_csv("Data/train.csv")
testData = pd.read_csv("Data/test.csv")

#print(trainData.head())

# data = censusData.drop(columns="class")
# target = censusData["class"]
trainDataSmall = trainData[trainData.columns[9900:10002]]
testDataSmall = testData[testData.columns[9900:10001]]

# %%
trainDataClass = trainData["Outcome"]
trainDataIds = trainData["Id"]
trainDataFeatures = trainData.drop(columns = ["Outcome", "Id"])

testDataIds = testData["Id"]
testDataFeatures = testData.drop(columns = ["Id"])

X_train, X_test, y_train, y_test, id_train, id_test = train_test_split(trainDataFeatures, trainDataClass, trainDataIds, test_size = .2, train_size = .8, random_state=24)

# %%
display(trainDataClass)
# Out:
# 0       2
# 1       2
# 2       1
# 3       0
# 4       2
#        ..
# 1515    0
# 1516    3
# 1517    0
# 1518    3
# 1519    3
# Name: Outcome, Length: 1520, dtype: int64

# %%
samples = []
for i in range(4):
    indices = (trainData[trainData.Outcome == i]).index
    samples += (np.random.choice(indices, 742)).tolist()

    
    
    #downsampled = trainData["Outcome"][np.random.choice(trainData.shape[0], 741, replace=False)]

#trainData.shape[0]
#i_class1_downsampled = np.random.choice(i_class1, size=n_class0, replace=False)

#display(trainData.iloc[downsampledTrain,:])

downsampledTrain = trainData.iloc[samples,:]

display(downsampledTrain)
# Out:
#       Gene 1  Gene 2  Gene 3  Gene 4   Gene 5   Gene 6  Gene 7  Gene 8  \
# 772    174.0    31.0     3.0   149.0  29588.0  86826.0    59.0    46.0
# 870    113.0    31.0     5.0   115.0  32761.0  47313.0    59.0    41.0
# 854    275.0    31.0     5.0   130.0  28285.0  57066.0    35.0    45.0
# 4029   184.0    49.0     2.0   158.0  22709.0  63028.0    66.0    39.0
# 2447   145.0    36.0     2.0    73.0  39086.0  53715.0    49.0    14.0
# ...      ...     ...     ...     ...      ...      ...     ...     ...
# 3000   240.0    42.0     4.0   113.0  20513.0  77389.0    25.0     NaN
# 1565   177.0     NaN     4.0    46.0  24198.0  71003.0    36.0    26.0
# 2292     NaN    28.0     4.0   110.0  32040.0  51461.0    64.0    41.0
# 2376   227.0    52.0     2.0    91.0  16421.0  64216.0    33.0     NaN
# 1308   196.0    49.0     4.0    73.0  29609.0  70354.0    51.0    40.0
#
#       Gene 9  Gene 10  ...  Gene 9993  Gene 9994  Gene 9995  Gene 9996  \
# ...

# %%
trainDataClass = trainData["Outcome"]
trainDataFeatures = trainData.drop(columns = ["Outcome", "Id"])

X_train, X_test, y_train, y_test = train_test_split(trainDataFeatures, trainDataClass, test_size = 0.2, random_state = 24)

# model = LogisticRegression()

# model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t_/wz5wcv9x52jbwkh7hh8jcp7w0000gn/T/ipykernel_90947/353025872.py in <module>
#       6 model = LogisticRegression()
#       7
# ----> 8 model.fit(X_train, y_train)
#       9
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...

# %%
downTrainFeat = downsampledTrain.drop(columns=["Outcome", "Id"])
downTrainClass = downsampledTrain["Outcome"]

pipe = Pipeline([('std', preprocessing.StandardScaler()), ("KNN", KNNImputer()), 
                 ('logisticRegression', LogisticRegression())], verbose = True)

X_train, X_test, y_train, y_test = train_test_split(downTrainFeat, downTrainClass, test_size = 0.2, 
                                                    random_state = 24)

# %%
pipe.fit(X_train, y_train)
# Out:
# [Pipeline] ............... (step 1 of 3) Processing std, total=   1.2s
# [Pipeline] ............... (step 2 of 3) Processing KNN, total= 8.1min
# [Pipeline]  (step 3 of 3) Processing logisticRegression, total=   2.0s
# Pipeline(steps=[('std', StandardScaler()), ('KNN', KNNImputer()),
#                 ('logisticRegression', LogisticRegression())],
#          verbose=True)

# %%
MLAssThree = pipe.predict(X_test)

# %%
#MLAssThreeTwo = list(MLAssThree)
MLAssThreeTwo = MLAssThree.copy()
MLAssThreeTwo = pd.DataFrame(MLAssThreeTwo, columns=["Outcome"])
indices = pd.DataFrame(trainData.iloc[list(X_test.index)]["Id"])
display(indices)
MLAssThreeThree = MLAssThreeTwo
display(MLAssThreeThree)

final_out = pd.concat([indices["Id"], MLAssThreeThree["Outcome"]], axis=1)
display(final_out)
# Out:
#         Id
# 4072  3918
# 2854   250
# 1839  1879
# 3204    51
# 2305  3381
# ...    ...
# 199   4179
# 415    509
# 1787  2280
# 110    485
# 633   3888
#
# [594 rows x 1 columns]
#      Outcome
# 0          0
# 1          3
# 2          0
# 3          0
# 4          1
# ..       ...
# 589        0
# 590        2
# 591        3
# 592        1
# 593        0
#
# [594 rows x 1 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/t_/wz5wcv9x52jbwkh7hh8jcp7w0000gn/T/ipykernel_90947/611197034.py in <module>
#       7 display(MLAssThreeThree)
#       8
# ----> 9 final_out = pd.concat([indices["Id"], MLAssThreeThree["Outcome"]], axis=1)
#      10 display(final_out)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# ...

# %%
#5 Nested Cross Validation

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, KFold

#data, target = load_breast_cancer(return_X_y=True)

#param_grid = {"C": [0.1, 1, 10], "gamma": [.01, .1]}
param_dist = {"PCA__n_components" : [50, 100, 200], "Imputing__n_neighbors" : [5, 10, 20]}
model_to_tune = Pipeline([
    ("Scaling", StandardScaler()), 
    ("Imputing", KNNImputer()),
    ("PCA", PCA()),
    ("Regression", LogisticRegression())], 
    verbose = True)

search = RandomizedSearchCV(
    estimator=model_to_tune, param_distributions=param_dist, n_jobs=4
)
search.fit(trainDataFeatures, trainDataClass)

print(f"The best parameters found are: {search.best_params_}")
print(f"The mean CV score of the best model is: {search.best_score_:.3f}")

# Declare the inner and outer cross-validation strategies
inner_cv = KFold(n_splits=5, shuffle=True, random_state=24)
outer_cv = KFold(n_splits=3, shuffle=True, random_state=24)

# Inner cross-validation for parameter search
model = RandomizedSearchCV(
    estimator=model_to_tune, param_distributions=param_dist, cv=inner_cv, n_jobs=4, return_estimator=True
)

# Outer cross-validation to compute the testing score
test_score = cross_val_score(model, trainDataFeatures, trainDataClass, cv=outer_cv, n_jobs=4)
print(f"The mean score using nested cross-validation is: "
      f"{test_score.mean():.3f} +/- {test_score.std():.3f}")

test_score_not_nested = []
test_score_nested = []

# N_TRIALS = 5
# for i in range(N_TRIALS):
#     # For each trial, we use cross-validation splits on independently
#     # randomly shuffled data by passing distinct values to the random_state
#     # parameter.
#     inner_cv = KFold(n_splits=5, shuffle=True, random_state=i)
#     outer_cv = KFold(n_splits=3, shuffle=True, random_state=i)

#     # Non_nested parameter search and scoring
#     model = RandomizedSearchCV(estimator=model_to_tune, param_distributions=param_dist,
#                          cv=inner_cv, n_jobs=2)
#     model.fit(X_train, y_train)
#     test_score_not_nested.append(model.best_score_)

#     # Nested CV with parameter optimization
#     test_score = cross_val_score(model, X_train, y_train, cv=outer_cv, n_jobs=2)
#     test_score_nested.append(test_score.mean())
    
# all_scores = {
#     "Not nested CV": test_score_not_nested,
#     "Nested CV": test_score_nested,
# }
# all_scores = pd.DataFrame(all_scores)

# color = {"whiskers": "black", "medians": "black", "caps": "black"}
# all_scores.plot.box(color=color, vert=False)
# plt.xlabel("Accuracy")
# _ = plt.title("Comparison of mean accuracy obtained on the test sets with\n"
#               "and without nested cross-validation")
# Out:
# C:\Users\aldov\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:285: UserWarning: The total space of parameters 9 is smaller than n_iter=10. Running 9 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [Pipeline] ........... (step 1 of 4) Processing Scaling, total=   0.2s
# [Pipeline] .......... (step 2 of 4) Processing Imputing, total=  41.2s
# [Pipeline] ............... (step 3 of 4) Processing PCA, total=   0.2s
# [Pipeline] ........ (step 4 of 4) Processing Regression, total=   0.0s
# The best parameters found are: {'PCA__n_components': 50, 'Imputing__n_neighbors': 5}
# The mean CV score of the best model is: 0.381
# The mean score using nested cross-validation is: 0.372 +/- 0.016

# %%
model_e5 = Pipeline([
    ("Scaling", StandardScaler()), 
    ("Imputing", KNNImputer(n_neighbors = 50)),
    ("PCA", PCA(n_components = 5)),
    ("Regression", LogisticRegression())], 
    verbose = True)

model_e5.fit(trainDataFeatures, trainDataClass)
# Out:
# [Pipeline] ........... (step 1 of 4) Processing Scaling, total=   0.2s
# [Pipeline] .......... (step 2 of 4) Processing Imputing, total=  41.9s
# [Pipeline] ............... (step 3 of 4) Processing PCA, total=   0.1s
# [Pipeline] ........ (step 4 of 4) Processing Regression, total=   0.0s
# Pipeline(steps=[('Scaling', StandardScaler()),
#                 ('Imputing', KNNImputer(n_neighbors=50)),
#                 ('PCA', PCA(n_components=5)),
#                 ('Regression', LogisticRegression())],
#          verbose=True)

# %%
#model_e5.predict(testDataFeatures)

ids = pd.DataFrame(testDataIds, columns=["Id"])
e5_outcome = pd.DataFrame(model_e5.predict(testDataFeatures), columns=["Outcome"])
ids.index = range(len(e5_outcome))
e5_outcome = pd.concat([ids, e5_outcome], axis=1)
display(e5_outcome)
e5_outcome.to_csv("e5_outcome.csv", index=False)
# Out:
#        Id  Outcome
# 0     473        3
# 1     273        3
# 2    1885        3
# 3     629        3
# 4     609        3
# ..    ...      ...
# 475  1182        3
# 476   978        3
# 477  1716        3
# 478   766        3
# 479  1155        3
#
# [480 rows x 2 columns]

# %%
print((search.best_estimator_))
# Out:
# Pipeline(steps=[('Scaling', StandardScaler()), ('Imputing', KNNImputer()),
#                 ('PCA', PCA(n_components=50)),
#                 ('Regression', LogisticRegression())],
#          verbose=True)
